# %% [markdown]
# # Pre-requisite
# - We need to create a data lake account and also upload the input file to it
# - Also need to create Service Principal and then allow access to SP on the Data Lake container which contains input files

# %% [markdown]
# ## Import Data from Data Lake

# %%
# Specify the Data Lake account details
adlsAccountName = "dldatabricks21"
adlsContainerName = "inputdata"
adlsFolderName = "data"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Specify details of SP which will be used in this notebook to connect to the Data Lake account
applicationId = "b9344d96-c48b-426c-8551-68ee134b70ac"
authenticationKey = "cIpuAjg-wP3xKmG0Kel8_pefv7Q546ZfCe"
tenandId = "6bb2f9af-a0af-4c32-a5ec-5f7011d37551"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
endpoint = "https://login.microsoftonline.com/" + tenandId + "/oauth2/token"
source = "abfss://" + adlsContainerName + "@" + adlsAccountName + ".dfs.core.windows.net/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": applicationId,
           "fs.azure.account.oauth2.client.secret": authenticationKey,
           "fs.azure.account.oauth2.client.endpoint": endpoint}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
try:
  dbutils.fs.mount(source = source,mount_point = "/mnt/data",extra_configs = configs)
except Exception as e:
  pass
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.fs.unmount("/mnt/data")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs
ls /mnt/data/data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/</td><td>P_By_DEST_COUNTRY_NAME/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/</td><td>P_By_DEST_COUNTRY_NAME_2/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/all-summary.csv</td><td>all-summary.csv</td><td>12425516</td></tr><tr><td>dbfs:/mnt/data/data/gprby2_DEST_COUNTRY_NAME/</td><td>gprby2_DEST_COUNTRY_NAME/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/gprby_DEST_COUNTRY_NAME/</td><td>gprby_DEST_COUNTRY_NAME/</td><td>0</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import col, column, spark_partition_id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
flightData2015="dbfs:/mnt/data/data/all-summary.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
flightDataDF2015 = spark\
.read\
.option("inferSchema", "true")\
.option("header", "true")\
.csv(flightData2015)

flightDataDF2015=flightDataDF2015.withColumn("partitionID", spark_partition_id())
flightDataDF2015.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[62]: 3</div>

# %%
from pyspark.sql.functions import concat, collect_list, collect_set, concat_ws

#Notice that values in the column - DEST_COUNTRY_NAME are spead over all partitions. It will create shuffling issues if we do any operation based on DEST_COUNTRY_NAME
flightDataDF2015.groupBy("DEST_COUNTRY_NAME")\
.agg(concat_ws(", ", collect_set(flightDataDF2015.partitionID))).display(100)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DEST_COUNTRY_NAME</th><th>concat_ws(, , collect_set(partitionID))</th></tr></thead><tbody><tr><td>Afghanistan</td><td>0, 1, 2</td></tr><tr><td>Algeria</td><td>0, 1, 2</td></tr><tr><td>Angola</td><td>0, 1, 2</td></tr><tr><td>Anguilla</td><td>0, 1, 2</td></tr><tr><td>Antigua and Barbuda</td><td>0, 1, 2</td></tr><tr><td>Argentina</td><td>0, 1, 2</td></tr><tr><td>Aruba</td><td>0, 1, 2</td></tr><tr><td>Australia</td><td>0, 1, 2</td></tr><tr><td>Austria</td><td>0, 1, 2</td></tr><tr><td>Azerbaijan</td><td>0, 1, 2</td></tr><tr><td>Bahrain</td><td>0, 1, 2</td></tr><tr><td>Barbados</td><td>0, 1, 2</td></tr><tr><td>Belarus</td><td>0, 1, 2</td></tr><tr><td>Belgium</td><td>0, 1, 2</
><td>Hong Kong</td><td>0, 1, 2</td></tr><tr><td>Hungary</td><td>0, 1, 2</td></tr><tr><td>Iceland</td><td>0, 1, 2</td></tr><tr><td>India</td><td>0, 1, 2</td></tr><tr><td>Indonesia</td><td>0, 1, 2</td></tr><tr><td>Iraq</td><td>0, 1, 2</td></tr><tr><td>Ireland</td><td>0, 1, 2</td></tr><tr><td>Israel</td><td>0, 1, 2</td></tr><tr><td>Italy</td><td>0, 1, 2</td></tr><tr><td>Jamaica</td><td>0, 1, 2</td></tr><tr><td>Japan</td><td>0, 1, 2</td></tr><tr><td>Jordan</td><td>0, 1, 2</td></tr><tr><td>Kazakhstan</td><td>0, 1, 2</td></tr><tr><td>Kenya</td><td>0, 1, 2</td></tr><tr><td>Kiribati</td><td>0, 1, 2</td></tr><tr><td>Kosovo</td><td>0, 1, 2</td></tr><tr><td>Kuwait</td><td>0, 1, 2</td></tr><tr><td>Kyrgyzstan</td><td>0, 1, 2</td></tr><tr><td>Latvia</td><td>0, 1, 2</td></tr><tr><td>Lebanon</td><td>0, 1, 2</td></tr><tr><td>Liberia</td><td>0, 1, 2</td></ ...

# %% [markdown]
# ## Repartition based on a column using which we need to do group by

# %%
flightDataDF2015_rp=flightDataDF2015.repartition(100, col("DEST_COUNTRY_NAME")).sort("DEST_COUNTRY_NAME").withColumn("partitionID", spark_partition_id())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Notice that one column is aligned to a single partition. It will avoid shuffling issues
flightDataDF2015_rp.groupBy("DEST_COUNTRY_NAME")\
.agg(concat_ws(", ", collect_set(flightDataDF2015_rp.partitionID))).display(1000)

#flightDataDF2015_rp.sort("partitionID").show(20000)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DEST_COUNTRY_NAME</th><th>concat_ws(, , collect_set(partitionID))</th></tr></thead><tbody><tr><td>Afghanistan</td><td>0</td></tr><tr><td>Algeria</td><td>0</td></tr><tr><td>Angola</td><td>0</td></tr><tr><td>Anguilla</td><td>1</td></tr><tr><td>Antigua and Barbuda</td><td>2</td></tr><tr><td>Argentina</td><td>3</td></tr><tr><td>Aruba</td><td>4</td></tr><tr><td>Australia</td><td>4</td></tr><tr><td>Austria</td><td>5</td></tr><tr><td>Azerbaijan</td><td>6</td></tr><tr><td>Bahrain</td><td>7</td></tr><tr><td>Barbados</td><td>7</td></tr><tr><td>Belarus</td><td>8</td></tr><tr><td>Belgium</td><td>8</td></tr><tr><td>Belize</td><td>9</td></tr><tr><td>Bermuda</td><td>10</td></tr><tr><td>Bolivia</td><td>11</td></tr><tr><td>Bonaire, Sint Eustatius, and Saba</td><td>12</td></tr><tr><td>Brazil</td><td>12</td></tr><tr><td>British Virgin Islands</td><td>13</td></tr><tr><td>Brunei</td><td>14</td></tr><tr><td>Bulgaria</td><td>14</td></tr><tr><td>Burkina Faso</td><td>15</td></tr><tr><td>Burundi</td><td>15</td></tr><tr><td>Cameroon</td><td>15</td></tr><tr><td>Canada</td><td>15</td></tr><tr><td>Cape Verde</td><td>16</td></tr><tr><td>Cayman Islands</td><td>17</td></tr><tr><td>Chad</td><td>17</td></tr><tr><td

# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dataFrameWay = flightDataDF2015\
.groupBy("dest_country_name")\
.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# The physical execution plans are almost ame either way
sqlWay.explain()
dataFrameWay.explain()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">== Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[dest_country_name#4602], functions=[finalmerge_count(merge count#4706L) AS count(1)#4692L])
#    +- Exchange hashpartitioning(dest_country_name#4602, 200), ENSURE_REQUIREMENTS, [id=#9821]
#       +- HashAggregate(keys=[dest_country_name#4602], functions=[partial_count(1) AS count#4706L])
#          +- FileScan csv [DEST_COUNTRY_NAME#4602] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex[dbfs:/mnt/data/data/all-summary.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct&lt;DEST_COUNTRY_NAME:string&gt;
#
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[dest_country_name#4602], functions=[finalmerge_count(merge count#4711L) AS count(1)#4701L])
#    +- Exchange hashpartitioning(dest_country_name#4602, 200), ENSURE_REQUIREMENTS, [id=#9867]
#       +- HashAggregate(keys=[dest_country_name#4602], functions=[partial_count(1) AS count#4711L])
#          +- FileScan csv [DEST_COUNTRY_NAME#4602] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex[dbfs:/mnt/data/data/all-summary.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct&lt;DEST_COUNTRY_NAME:string&gt;
#
#
# </div>

# %% [markdown]
# ## Grouping on regular dataframe and inspect performance

# %%
flightDataDF2015_groupBy=flightDataDF2015\
.groupBy("DEST_COUNTRY_NAME")\
.sum("count")\
.withColumnRenamed("sum(count)", "destination_total")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Only 3 partitions are created and group by will result in shuffling
flightDataDF2015.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[70]: 3</div>

# %%
# Let's save the results. This will initiate Action and also to the data shuffling
dbutils.fs.rm("/mnt/data/data/gprby_DEST_COUNTRY_NAME",True)
#Here data shuffleing will happen which is an expensive operation
flightDataDF2015_groupBy.write.mode('overwrite').format("csv").option("header", "true").save("dbfs:/mnt/data/data/gprby_DEST_COUNTRY_NAME")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs
ls /mnt/data/data/gprby_DEST_COUNTRY_NAME
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/data/data/gprby_DEST_COUNTRY_NAME/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/gprby_DEST_COUNTRY_NAME/_committed_129582346818394882</td><td>_committed_129582346818394882</td><td>113</td></tr><tr><td>dbfs:/mnt/data/data/gprby_DEST_COUNTRY_NAME/_started_129582346818394882</td><td>_started_129582346818394882</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/gprby_DEST_COUNTRY_NAME/part-00000-tid-129582346818394882-ca1469c7-b336-43e5-a27e-395ba45a0ccb-9312-1-c000.csv</td><td>part-00000-tid-129582346818394882-ca1469c7-b336-43e5-a27e-395ba45a0ccb-9312-1-c000.csv</td><td>2693</td></tr></tbody></table></div>

# %% [markdown]
# ## Grouping on repartitioned dataframe and inspect performance

# %%
# No/Minimal shuffling will happen
flightDataDF2015_rp_groupBy=flightDataDF2015_rp\
.groupBy("dest_country_name")\
.sum("count")\
.withColumnRenamed("sum(count)", "destination_total")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs
></tr><tr><td>Slovakia</td><td>United States</td><td>0</td></tr><tr><td>Suriname</td><td>United States</td><td>0</td></tr><tr><td>Mexico</td><td>United States</td><td>3</td></tr><tr><td>United States</td><td>Cyprus</td><td>2</td></tr><tr><td>Ecuador</td><td>United States</td><td>5</td></tr><tr><td>United States</td><td>Bosnia and Herzegovina</td><td>3</td></tr><tr><td>United States</td><td>Portugal</td><td>5</td></tr><tr><td>United States</td><td>Costa Rica</td><td>3</td></tr><tr><td>United States</td><td>Guatemala</td><td>2</td></tr><tr><td>United States</td><td>Suriname</td><td>4</td></tr><tr><td>Colombia</td><td>United States</td><td>3</td></tr><tr><td>United States</td><td>Cape Verde</td><td>5</td></tr><tr><td>United States</td><td>Jamaica</td><td>3</td></tr><tr><td>United States</td><td>Malaysia</td><td>2</td></tr><tr><td>Norway</td><td>United States</td><td>0</td></tr><tr><td>United States</td><td>Morocco</td><td>3</td></tr><tr><td>Thailand</td><td>United States</td><td>0</td></tr><tr><td>Venezuela</td><td>United States</td><td>4</td></tr><tr><td>United States</td><td>Palau</td><td>0</td></tr><tr><td>United States</td><td>Samoa</td><td>2</td></tr><tr><td>United States</td><td>Algeria</td><td>5</td></tr><tr><td>United States</td><td>Venezuela</td><td>5</td></tr><tr><td>Panama</td><t ...

# %%
flightDataDF2015.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: 3</div>

# %% [markdown]
# ## Can specify to create multiple files, one for each value in the columns

# %%
# Slow Performance as all data is to be reshuffled
dbutils.fs.rm("dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME", True)
flightDataDF2015.write.partitionBy("DEST_COUNTRY_NAME").format("csv").save("dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs
ls /mnt/data/data/P_By_DEST_COUNTRY_NAME
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Afghanistan/</td><td>DEST_COUNTRY_NAME=Afghanistan/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Algeria/</td><td>DEST_COUNTRY_NAME=Algeria/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Angola/</td><td>DEST_COUNTRY_NAME=Angola/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Anguilla/</td><td>DEST_COUNTRY_NAME=Anguilla/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Antigua and Barbuda/</td><td>DEST_COUNTRY_NAME=Antigua and Barbuda/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Argentina/</td><td>DEST_COUNTRY_NAME=Argentina/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Aruba/</td><td>DEST_COUNTRY_NAME=Aruba/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Australia/</td><td>DEST_COUNTRY_NAME=Australia/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Austria/</td><td>DEST_COUNTRY_NAME=Austria/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Azerbaijan/</td><td>DEST_COUNTRY_NAME=Azerbaijan/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Bahrain/</td><td>DEST_COUNTRY_NAME=Bahrain/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Barbados/</td><td>DEST_COUNTRY_NAME=Barbados/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Belarus/</td><td>DEST_COUNTRY_NAME=Belarus/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Belgium/</td><td>DEST_COUNTRY_NAME=Belgium/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Belize/</td><td>DEST_COUNTRY_NAME=Belize/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Bermuda/</td><td>DEST_COUNTRY_NAME=Bermuda/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Bolivia/</td><td>DEST_COUNTRY_NAME=Bolivia/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Bonaire, Sint Eustatius, and Saba/</td><td>DEST_COUNTRY_NAME=Bonaire, Sint Eustatius, and Saba/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Brazil/</td><td>DEST_COUNTRY_NAME=Brazil/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=British Virgin Islands/</td><td>DEST_COUNTRY_NAME=British Virgin Islands/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Brunei/</td><td>DEST_COUNTRY_NAME=Brunei/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Bulgaria/</td><td>DEST_COUNTRY_NAME=Bulgaria/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Burkina Faso/</td><td>DEST_COUNTRY_NAME=Burkina Faso/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Burundi/</td><td>DEST_COUNTRY_NAME=Burundi/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Cameroon/</td><td>DEST_COUNTRY_NAME=Cameroon/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Canada/</td><td>DEST_COUNTRY_NAME=Canada/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Cape Verde/</td><td>DEST_COUNTRY_NAME=Cape Verde/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME/DEST_COUNTRY_NAME=Cayman Islands/</td><td>DEST_COUNTRY_NAME=Cayman Island ...

# %%
# Fast Performance as all data is spread across partitions with each executer
dbutils.fs.rm("dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2", True)
flightDataDF2015_rp.write.partitionBy("DEST_COUNTRY_NAME").format("csv").save("dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs
ls /mnt/data/data/P_By_DEST_COUNTRY_NAME_2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Afghanistan/</td><td>DEST_COUNTRY_NAME=Afghanistan/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Algeria/</td><td>DEST_COUNTRY_NAME=Algeria/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Angola/</td><td>DEST_COUNTRY_NAME=Angola/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Anguilla/</td><td>DEST_COUNTRY_NAME=Anguilla/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Antigua and Barbuda/</td><td>DEST_COUNTRY_NAME=Antigua and Barbuda/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Argentina/</td><td>DEST_COUNTRY_NAME=Argentina/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Aruba/</td><td>DEST_COUNTRY_NAME=Aruba/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Australia/</td><td>DEST_COUNTRY_NAME=Australia/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Austria/</td><td>DEST_COUNTRY_NAME=Austria/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Azerbaijan/</td><td>DEST_COUNTRY_NAME=Azerbaijan/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Bahrain/</td><td>DEST_COUNTRY_NAME=Bahrain/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Barbados/</td><td>DEST_COUNTRY_NAME=Barbados/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Belarus/</td><td>DEST_COUNTRY_NAME=Belarus/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Belgium/</td><td>DEST_COUNTRY_NAME=Belgium/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Belize/</td><td>DEST_COUNTRY_NAME=Belize/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Bermuda/</td><td>DEST_COUNTRY_NAME=Bermuda/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Bolivia/</td><td>DEST_COUNTRY_NAME=Bolivia/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Bonaire, Sint Eustatius, and Saba/</td><td>DEST_COUNTRY_NAME=Bonaire, Sint Eustatius, and Saba/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Brazil/</td><td>DEST_COUNTRY_NAME=Brazil/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=British Virgin Islands/</td><td>DEST_COUNTRY_NAME=British Virgin Islands/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Brunei/</td><td>DEST_COUNTRY_NAME=Brunei/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Bulgaria/</td><td>DEST_COUNTRY_NAME=Bulgaria/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Burkina Faso/</td><td>DEST_COUNTRY_NAME=Burkina Faso/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Burundi/</td><td>DEST_COUNTRY_NAME=Burundi/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Cameroon/</td><td>DEST_COUNTRY_NAME=Cameroon/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Canada/</td><td>DEST_COUNTRY_NAME=Canada/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME=Cape Verde/</td><td>DEST_COUNTRY_NAME=Cape Verde/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2/DEST_COUNTRY_NAME ...

# %%
# Multiple executers will load the data paralally
df1 = spark.read.format("csv").schema(myManualSchema)\
.load("dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Multiple executers will load the data paralally
df1 = spark.read.format("csv").schema(myManualSchema)\
.load("dbfs:/mnt/data/data/P_By_DEST_COUNTRY_NAME_2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df1.createOrReplaceTempView("flight_data_2015")
sqlWay = spark\
.sql("""
select *
from flight_data_2015
where dest_country_name='United States'
""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%