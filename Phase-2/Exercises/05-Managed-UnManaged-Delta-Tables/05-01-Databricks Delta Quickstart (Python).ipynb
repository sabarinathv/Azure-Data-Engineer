# %%
from pyspark.sql.functions import expr
from pyspark.sql.functions import from_unixtime

events = spark.read \
  .option("inferSchema", "true") \
  .json("/databricks-datasets/structured-streaming/events/") \
  .withColumn("date", expr("time")) \
  .drop("time") \
  .withColumn("date", from_unixtime("date", 'yyyy-MM-dd'))
  
display(events)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>date</th></tr></thead><tbody><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016- ...

# %%
events.write.format("delta").mode("overwrite").partitionBy("date").save("/delta/events/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs
ls /delta/events/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/delta/events/_delta_log/</td><td>_delta_log/</td><td>0</td></tr><tr><td>dbfs:/delta/events/date=2016-07-24/</td><td>date=2016-07-24/</td><td>0</td></tr><tr><td>dbfs:/delta/events/date=2016-07-25/</td><td>date=2016-07-25/</td><td>0</td></tr><tr><td>dbfs:/delta/events/date=2016-07-26/</td><td>date=2016-07-26/</td><td>0</td></tr><tr><td>dbfs:/delta/events/date=2016-07-27/</td><td>date=2016-07-27/</td><td>0</td></tr><tr><td>dbfs:/delta/events/date=2016-07-28/</td><td>date=2016-07-28/</td><td>0</td></tr></tbody></table></div>

# %%
events_delta = spark.read.format("delta").load("/delta/events/")

display(events_delta)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>time</th><th>date</th></tr></thead><tbody><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Open</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td>Close</td><td>null</td><td>2016-07-26</td></tr><tr><td> ...

# %%
display(spark.sql("DROP TABLE IF EXISTS events"))

display(spark.sql("CREATE TABLE events USING DELTA LOCATION '/delta/events/'"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
events_delta.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: 100000</div>

# %%
from pyspark.sql.functions import count
display(events_delta.groupBy("action","date").agg(count("action").alias("action_count")).orderBy("date", "action"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>date</th><th>action_count</th></tr></thead><tbody><tr><td>Close</td><td>2016-07-26</td><td>20165</td></tr><tr><td>Open</td><td>2016-07-26</td><td>21176</td></tr><tr><td>Close</td><td>2016-07-27</td><td>24015</td></tr><tr><td>Open</td><td>2016-07-27</td><td>24002</td></tr><tr><td>Close</td><td>2016-07-28</td><td>5820</td></tr><tr><td>Open</td><td>2016-07-28</td><td>4822</td></tr></tbody></table></div>

# %%
historical_events = spark.read \
  .option("inferSchema", "true") \
  .json("/databricks-datasets/structured-streaming/events/") \
  .withColumn("date", expr("time-172800")) \
  .drop("time") \
  .withColumn("date", from_unixtime("date", 'yyyy-MM-dd'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
historical_events.write.format("delta").mode("append").partitionBy("date").save("/delta/events/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs
ls /delta/events/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/delta/events/_delta_log/</td><td>_delta_log/</td><td>0</td></tr><tr><td>dbfs:/delta/events/date=2016-07-24/</td><td>date=2016-07-24/</td><td>0</td></tr><tr><td>dbfs:/delta/events/date=2016-07-25/</td><td>date=2016-07-25/</td><td>0</td></tr><tr><td>dbfs:/delta/events/date=2016-07-26/</td><td>date=2016-07-26/</td><td>0</td></tr><tr><td>dbfs:/delta/events/date=2016-07-27/</td><td>date=2016-07-27/</td><td>0</td></tr><tr><td>dbfs:/delta/events/date=2016-07-28/</td><td>date=2016-07-28/</td><td>0</td></tr></tbody></table></div>

# %%
display(events_delta.groupBy("action","date").agg(count("action").alias("action_count")).orderBy("date", "action"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>date</th><th>action_count</th></tr></thead><tbody><tr><td>Close</td><td>2016-07-24</td><td>20165</td></tr><tr><td>Open</td><td>2016-07-24</td><td>21176</td></tr><tr><td>Close</td><td>2016-07-25</td><td>24015</td></tr><tr><td>Open</td><td>2016-07-25</td><td>24002</td></tr><tr><td>Close</td><td>2016-07-26</td><td>25985</td></tr><tr><td>Open</td><td>2016-07-26</td><td>25998</td></tr><tr><td>Close</td><td>2016-07-27</td><td>24015</td></tr><tr><td>Open</td><td>2016-07-27</td><td>24002</td></tr><tr><td>Close</td><td>2016-07-28</td><td>5820</td></tr><tr><td>Open</td><td>2016-07-28</td><td>4822</td></tr></tbody></table></div>

# %%
events_delta.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: 200000</div>

# %%
dbutils.fs.ls("dbfs:/delta/events/date=2016-07-25/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: [FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00000-5fc7024c-4dbd-4150-9b33-ded37d924a81.c000.snappy.parquet&#39;, name=&#39;part-00000-5fc7024c-4dbd-4150-9b33-ded37d924a81.c000.snappy.parquet&#39;, size=2790),
#  FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00000-7644729d-07b9-47d1-b6df-45c6dd920cfd.c000.snappy.parquet&#39;, name=&#39;part-00000-7644729d-07b9-47d1-b6df-45c6dd920cfd.c000.snappy.parquet&#39;, size=2790),
#  FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00000-d327d8a5-91bb-42d7-99aa-a0f64802e54b.c000.snappy.parquet&#39;, name=&#39;part-00000-d327d8a5-91bb-42d7-99aa-a0f64802e54b.c000.snappy.parquet&#39;, size=2790),
#  FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00001-0e420e57-42ef-4f66-8604-3540789c517a.c000.snappy.parquet&#39;, name=&#39;part-00001-0e420e57-42ef-4f66-8604-3540789c517a.c000.snappy.parquet&#39;, size=10307),
#  FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00001-2785d593-95ab-47b0-867f-6ff5636cc945.c000.snappy.parquet&#39;, name=&#39;part-00001-2785d593-95ab-47b0-867f-6ff5636cc945.c000.snappy.parquet&#39;, size=1589),
#  FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00001-c9b02a74-495d-4f58-ac9c-27ef71258189.c000.snappy.parquet&#39;, name=&#39;part-00001-c9b02a74-495d-4f58-ac9c-27ef71258189.c000.snappy.parquet&#39;, size=1589),
#  FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00001-fbbb4db2-6d83-4b8c-8fbe-d141f8b552c1.c000.snappy.parquet&#39;, name=&#39;part-00001-fbbb4db2-6d83-4b8c-8fbe-d141f8b552c1.c000.snappy.parquet&#39;, size=1589),
#  FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00002-00340426-67f2-4d3f-be48-f46214fee54b.c000.snappy.parquet&#39;, name=&#39;part-00002-00340426-67f2-4d3f-be48-f46214fee54b.c000.snappy.parquet&#39;, size=1674),
#  FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00002-6141b980-18e7-450f-8b81-31ef96be91d4.c000.snappy.parquet&#39;, name=&#39;part-00002-6141b980-18e7-450f-8b81-31ef96be91d4.c000.snappy.parquet&#39;, size=1674),
#  FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00002-cd483524-be01-43cd-afcc-896f59a8d3fa.c000.snappy.parquet&#39;, name=&#39;part-00002-cd483524-be01-43cd-afcc-896f59a8d3fa.c000.snappy.parquet&#39;, size=1674),
#  FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00003-bceb65d4-cbdc-4189-a773-552578c66e70.c000.snappy.parquet&#39;, name=&#39;part-00003-bceb65d4-cbdc-4189-a773-552578c66e70.c000.snappy.parquet&#39;, size=2359),
#  FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00003-c30804f1-1d16-4bcf-9294-2e49f3558daf.c000.snappy.parquet&#39;, name=&#39;part-00003-c30804f1-1d16-4bcf-9294-2e49f3558daf.c000.snappy.parquet&#39;, size=2359),
#  FileInfo(path=&#39;dbfs:/delta/events/date=2016-07-25/part-00003-ded3d09c-550f-4d73-91bd-8ba7b286fc58.c000.snappy.parquet&#39;, name=&#39;part-00003-ded3d09c-550f-4d73-91bd-8ba7b286fc58.c000.snappy.parquet&#39;, size=2359)]</div>

# %%
# Optimizes the layout of Delta Lake data
display(spark.sql("OPTIMIZE events"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>null</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 5, null, 0)</td></tr></tbody></table></div>

# %%
display(spark.sql("DESCRIBE HISTORY events"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th></tr></thead><tbody><tr><td>6</td><td>2021-07-02T00:19:14.000+0000</td><td>4475346586554357</td><td>atin.intellipaat@gmail.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], zOrderBy -> [], batchId -> 0, auto -> false)</td><td>null</td><td>List(1686769686243328)</td><td>0628-054729-nylon639</td><td>5</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 22, numRemovedBytes -> 37842, p25FileSize -> 6049, minFileSize -> 1977, numAddedFiles -> 5, maxFileSize -> 7300, p75FileSize -> 6883, p50FileSize -> 6883, numAddedBytes -> 29092)</td><td>null</td></tr><tr><td>5</td><td>2021-07-02T00:18:48.000+0000</td><td>4475346586554357</td><td>atin.intellipaat@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> ["date"])</td><td>null</td><td>List(1686769686243328)</td><td>0628-054729-nylon639</td><td>4</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 11, numOutputBytes -> 18921, numOutputRows -> 100000)</td><td>null</td></tr><tr><td>4</td><td>2021-07-02T00:17:45.000+0000</td><td>4475346586554357</td><td>atin.intellipaat@gmail.com</td><td>WRITE</td><td>Map(mode -> Overwrite, partitionBy -> ["date"])</td><td>null</td><td>List(1686769686243328)</td><td>0628-054729-nylon639</td><td>3</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 11, numOutputBytes -> 18921, numOutputRows -> 100000)</td><td>null</td></tr><tr><td>3</td><td>2021-07-01T23:50:15.000+0000</td><td>4475346586554357</td><td>atin.intellipaat@gmail.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], zOrderBy -> [], batchId -> 0, auto -> false)</td><td>null</td><td>List(1686769686243328)</td><td>0628-054729-nylon639</td><td>2</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 33, numRemovedBytes -> 533735, p25FileSize -> 11372, minFileSize -> 10307, numAddedFiles -> 5, maxFileSize -> 166638, p75FileSize -> 146403, p50FileSize -> 53959, numAddedBytes -> 388679)</td><td>null</td></tr><tr><td>2</td><td>2021-07-01T23:46:37.000+0000</td><td>4475346586554357</td><td>atin.intellipaat@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> ["date"])</td><td>null</td><td>List(1686769686243328)</td><td>0628-054729-nylon639</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 11, numOutputBytes -> 18921, numOutputRows -> 100000)</td><td>null</td></tr><tr><td>1</td><td>2021-07-01T23:44:41.000+0000</td><td>4475346586554357</td><td>atin.intellipaat@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> ["date"])</td><td>null</td><td>List(1686769686243328)</td><td>0628-054729-nylon639</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 11, numOutputBytes -> 18921, numOutputRows -> 100000)</td><td>null</td></tr><tr><td>0</td><td>2021-07-01T23:42:12.000+0000</td><td>4475346586554357</td><td>atin.intellipaat@gmail.com</td><td>WRITE</td><td>Map(mode -> Overwrite, partitionBy -> ["date"])</td><td>null</td><td>List(1686769686243328)</td><td>0628-054729-nylon639</td><td>null</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 11, numOutputBytes -> 495893, numOutputRows -> 100000)</td><td>null</td></tr></tbody></table></div>

# %%
display(spark.sql("DESCRIBE DETAIL events"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th></tr></thead><tbody><tr><td>delta</td><td>3dcd8240-e48d-4d98-a2b5-36e2973b8279</td><td>default.events</td><td>null</td><td>dbfs:/delta/events</td><td>2021-07-01T23:42:02.884+0000</td><td>2021-07-02T00:19:14.000+0000</td><td>List(date)</td><td>5</td><td>29092</td><td>Map()</td><td>1</td><td>2</td></tr></tbody></table></div>

# %%
display(spark.sql("DESCRIBE FORMATTED events"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>action</td><td>string</td><td></td></tr><tr><td>time</td><td>bigint</td><td></td></tr><tr><td>date</td><td>string</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Partitioning</td><td></td><td></td></tr><tr><td>Part 0</td><td>date</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Name</td><td>default.events</td><td></td></tr><tr><td>Location</td><td>dbfs:/delta/events</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
